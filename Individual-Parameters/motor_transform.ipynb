# %%
import sys
sys.path.append('../')

# %%
import ctn_benchmark

# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from hyperopt import fmin, hp, tpe, Trials, rand
import pickle
import hyperopt

# %%
import vision_benchmarks
reload (vision_benchmarks)
# Out:
# <module 'vision_benchmarks' from '../vision_benchmarks.pyc'>

# %%
def objective(x):
    vals = vision_benchmarks.Vision_Model().run(
        #motor_feedback = x['motor_feedback'],
        motor_transform = x['motor_transform'],
        #finger_feedback = x['finger_feedback'],
        #motor_to_fingers_strength = x['motor_to_fingers_strength']
    )
    return {
        'loss': 
            abs(vals['MC_to_finger'] - 0.025) + abs(vals['finger_to_end'] - 0.03) + abs(vals['PMC_to_MC'] - 0.025),
        
        'status': hyperopt.STATUS_OK,
    }
trials = Trials()
best = fmin(objective,
            space = {#'motor_feedback': hp.uniform('motor_feedback', 0, 1),
                     'motor_transform': hp.quniform('motor_transform', 0, 15, 1),
                     #'finger_feedback': hp.uniform('finger_feedback', 0, 1),
                     #'motor_to_fingers_strength': hp.uniform('motor_to_fingers_strength', 0, 1)
                    },
            algo = rand.suggest,
            max_evals = 100,
            trials = trials
           )
pickle.dump({'Trials': trials, 'Best': best}, open ('motor_transform_data', 'w'))
# Out:
# running Vision_Model#20160728-171356-406f8c6d
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 10.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.016
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.019000000000000003
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-171443-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-171528-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-171614-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-171658-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-171746-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 13.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-171830-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 9.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.017000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-171914-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-171958-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 10.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.016
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.019000000000000003
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172046-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 12.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.014000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172130-7739df34
# Simulation finished in 0:00:32.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 6.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.013000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0030000000000000027
# V1_to_AIT = 0.023
# finger_to_end = 0.017000000000000008
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172220-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 12.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.014000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172303-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 10.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.016
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.019000000000000003
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172346-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172430-7739df34
# Simulation finished in 0:00:34.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172523-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 11.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.013000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.013000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.013000000000000005
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172606-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 7.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.017000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0040000000000000036
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172650-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 11.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.013000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.013000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.013000000000000005
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172736-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172821-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172908-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 11.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.013000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.013000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.013000000000000005
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-172955-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 1.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.27600000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.017999999999999988
# V1_to_AIT = 0.023
# finger_to_end = 0.13300000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173042-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 4.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.010999999999999996
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.0059999999999999915
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173125-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 7.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.017000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0040000000000000036
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173214-7739df34
# Simulation finished in 0:00:33.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 6.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.013000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0030000000000000027
# V1_to_AIT = 0.023
# finger_to_end = 0.017000000000000008
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173307-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 9.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.017000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173354-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 13.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173442-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173530-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 12.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.014000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173617-7739df34
# Simulation finished in 0:00:34.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173709-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173753-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173837-7739df34
# Simulation finished in 0:00:39.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 10.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.016
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.019000000000000003
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-173934-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 5.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.0020000000000000018
# V1_to_AIT = 0.023
# finger_to_end = 0.017999999999999995
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174018-7739df34
# Simulation finished in 0:00:32.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 12.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.014000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174108-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 1.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.27600000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.017999999999999988
# V1_to_AIT = 0.023
# finger_to_end = 0.13300000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174152-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 12.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.014000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174238-7739df34
# Simulation finished in 0:00:33.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 13.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174332-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174418-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 5.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.0020000000000000018
# V1_to_AIT = 0.023
# finger_to_end = 0.017999999999999995
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174501-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 10.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.016
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.019000000000000003
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174546-7739df34
# Simulation finished in 0:00:36.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 5.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.0020000000000000018
# V1_to_AIT = 0.023
# finger_to_end = 0.017999999999999995
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174640-7739df34
# Simulation finished in 0:00:39.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 12.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.014000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174737-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 4.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.010999999999999996
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.0059999999999999915
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174821-7739df34
# Simulation finished in 0:00:40.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 13.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-174920-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 9.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.017000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175011-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 10.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.016
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.019000000000000003
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175058-7739df34
# Simulation finished in 0:00:32.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 1.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.27600000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.017999999999999988
# V1_to_AIT = 0.023
# finger_to_end = 0.13300000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175150-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 10.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.016
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.009000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.019000000000000003
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175236-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175325-7739df34
# Simulation finished in 0:00:35.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 1.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.27600000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.017999999999999988
# V1_to_AIT = 0.023
# finger_to_end = 0.13300000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175419-7739df34
# Simulation finished in 0:00:33.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 7.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.017000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0040000000000000036
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175510-7739df34
# Simulation finished in 0:00:32.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 12.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.014000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175602-7739df34
# Simulation finished in 0:00:32.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 5.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.0020000000000000018
# V1_to_AIT = 0.023
# finger_to_end = 0.017999999999999995
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175654-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175741-7739df34
# Simulation finished in 0:00:43.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175843-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-175934-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-180018-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-180102-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 13.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# ...
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 13.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-181844-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-181933-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 14.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.019999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182016-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 6.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.013000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0030000000000000027
# V1_to_AIT = 0.023
# finger_to_end = 0.017000000000000008
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182100-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182144-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182227-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 13.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.015000000000000006
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182312-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 1.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.27600000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.017999999999999988
# V1_to_AIT = 0.023
# finger_to_end = 0.13300000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182356-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 12.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.014000000000000005
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182456-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 3.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.0050000000000000044
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.009999999999999995
# V1_to_AIT = 0.023
# finger_to_end = 0.017000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182547-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 3.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.0050000000000000044
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.009999999999999995
# V1_to_AIT = 0.023
# finger_to_end = 0.017000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182631-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 1.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.27600000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.017999999999999988
# V1_to_AIT = 0.023
# finger_to_end = 0.13300000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182719-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182807-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 1.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.27600000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.017999999999999988
# V1_to_AIT = 0.023
# finger_to_end = 0.13300000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182851-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-182935-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 5.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.0020000000000000018
# V1_to_AIT = 0.023
# finger_to_end = 0.017999999999999995
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-183036-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 0.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.013000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.056000000000000008
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-183128-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 5.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.0020000000000000018
# V1_to_AIT = 0.023
# finger_to_end = 0.017999999999999995
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-183211-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160728-183255-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 8.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = -0.0080000000000000071
# V1_to_AIT = 0.023
# finger_to_end = 0.014999999999999999
# retina_to_V1 = 0.0050000000000000001

# %%
print(best)
# Out:
# {'motor_transform': 2.0}

# %%
import pandas
import seaborn as sns
data = ctn_benchmark.Data('data')
df = pandas.DataFrame(data.data
u'bytearray': <type 'bytearray'>, u'IndexErro...
# 4    {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 9    {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 10   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 14   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 18   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 19   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 21   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 23   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 25   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 27   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 31   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 39   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 42   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 43   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 45   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 53   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 58   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 61   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 67   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 68   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 77   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 85   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 86   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 89   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 94   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 95   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 98   {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 103  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 104  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# ..                                                 ...
# 645  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 651  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 652  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 653  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 663  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 665  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 670  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 671  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 672  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 673  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 676  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 683  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 686  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 687  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 691  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 703  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 705  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 708  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 710  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 711  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 717  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 725  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 727  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 729  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 730  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 732  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 735  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 742  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 744  {u'bytearray': <type 'bytearray'>, u'IndexErro...
# 746  {u'bytearray': <type 'bytearray'>, u'IndexErro...
#
#                            ...                           _gui  _hide_overlay  \
# 3                          ...                          False          False
# 4                          ...                          False          False
# 9                          ...                          False          False
# 10                         ...                          False          False
# 14                         ...                          False          False
# 18                         ...                          False          False
# 19                         ...                          False          False
# 21                         ...                          False          False
# 23                         ...                          False          False
# 25                         ...                          False          False
# 27                         ...                          False          False
# 31                         ...                          False          False
# 39                         ...                          False          False
# 42                         ...                          False          False
# 43                         ...                          False          False
# 45                         ...                          False          False
# 53                         ...                          False          False
# 58                         ...                          False          False
# 61                         ...                          False          False
# 67                         ...                          False          False
# 68                         ...                          False          False
# 77                         ...                          False          False
# 85                         ...                          False          False
# 86                         ...                          False          False
# 89                         ...                          False          False
# 94                         ...                          False          False
# 95                         ...                          False          False
# 98                         ...                          False          False
# 103                        ...                          False          False
# 104                        ...                          False          False
# ..                         ...                            ...            ...
# 645                        ...                          False          False
# 651                        ...                          False          False
# 652                        ...                          False          False
# 653                        ...                          False          False
# 663                        ...                          False          False
# 665                        ...                          False          False
# 670                        ...                          False          False
# 671                        ...                          False          False
# 672                        ...                          False          False
# 673                        ...                          False          False
# 676                        ...                          False          False
# 683                        ...                          False          False
# 686                        ...                          False          False
# 687                        ...                          False          False
# 691                        ...                          False          False
# 703                        ...                          False          False
# 705                        ...                          False          False
# 708                        ...                          False          False
# 710                        ...                          False          False
# 711                        ...                          False          False
# 717                        ...                          False          False
# 725                        ...                          False          False
# 727                        ...                          False          False
# 729                        ...                          False          False
# 730                        ...                          False          False
# 732                        ...                          False          False
# 735                        ...                          False          False
# 742                        ...                          False          False
# 744                        ...                          False          False
# 746                        ...                          False          False
#
#      _motor_feedback  _motor_to_fingers_strength _motor_transform  \
# 3           0.068487                    0.807972               10
# 4           0.068487                    0.807972                6
# 9           0.068487                    0.807972               14
# 10          0.068487                    0.807972                1
# 14          0.068487                    0.807972               14
# 18          0.068487                    0.807972               10
# 19          0.068487                    0.807972                1
# 21          0.068487                    0.807972                3
# 23          0.068487                    0.807972               13
# 25          0.068487                    0.807972                6
# 27          0.068487                    0.807972               12
# 31          0.068487                    0.807972                8
# 39          0.068487                    0.807972               13
# 42          0.068487                    0.807972                9
# 43          0.068487                    0.807972                3
# 45          0.068487                    0.807972               11
# 653         0.419509         2      1          0.133         0.005
# 663         0.419509         2      1          0.016         0.005
# 665         0.419509         2      1          0.133         0.005
# 670         0.419509         2      1          0.015         0.005
# 671         0.419509         2      1          0.016         0.005
# 672         0.419509         2      1          0.018         0.005
# 673         0.419509         2      1          0.019         0.005
# 676         0.419509         2      1          0.133         0.005
# 683         0.419509         2      1          0.019         0.005
# 686         0.419509         2      1          0.015         0.005
# 687         0.419509         2      1          0.015         0.005
# 691         0.419509         2      1          0.013         0.005
# 703         0.419509         2      1          0.015         0.005
# 705         0.419509         2      1          0.018         0.005
# 708         0.419509         2      1          0.033         0.005
# 710         0.419509         2      1          0.018         0.005
# 711         0.419509         2      1          0.016         0.005
# 717         0.419509         2      1          0.016         0.005
# 725         0.419509         2      1          0.033         0.005
# 727         0.419509         2      1          0.033         0.005
# 729         0.419509         2      1          0.016         0.005
# 730         0.419509         2      1          0.018         0.005
# 732         0.419509         2      1          0.033         0.005
# 735         0.419509         2      1          0.016         0.005
# 742         0.419509         2      1          0.018         0.005
# 744         0.419509         2      1          0.033         0.005
# 746         0.419509         2      1          0.019         0.005
#
# [200 rows x 24 columns]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_motor_transform'
sns.regplot(x, y = 'PMC_to_MC', ax = ax1, data = df)
sns.regplot(x, y = 'MC_to_finger', ax = ax2, data = df)
sns.regplot(x, y = 'finger_to_end', ax = ax3, data = df)

# %% [markdown]
# It looks like there might be something happening between 0 and 2 so I guess I'll run hyperopt... again...

# %%
def objective(x):
    vals = vision_benchmarks.Vision_Model().run(
        #motor_feedback = x['motor_feedback'],
        motor_transform = x['motor_transform'],
        #finger_feedback = x['finger_feedback'],
        #motor_to_fingers_strength = x['motor_to_fingers_strength']
    )
    return {
        'loss': 
            abs(vals['MC_to_finger'] - 0.025) + abs(vals['finger_to_end'] - 0.03) + abs(vals['PMC_to_MC'] - 0.025),
        
        'status': hyperopt.STATUS_OK,
    }
trials = Trials()
best = fmin(objective,
            space = {#'motor_feedback': hp.uniform('motor_feedback', 0, 1),
                     'motor_transform': hp.quniform('motor_transform', 0, 2.4, 0.2),
                     #'finger_feedback': hp.uniform('finger_feedback', 0, 1),
                     #'motor_to_fingers_strength': hp.uniform('motor_to_fingers_strength', 0, 1)
                    },
            algo = rand.suggest,
            max_evals = 36,
            trials = trials
           )
pickle.dump({'Trials': trials, 'Best': best}, open ('motor_transform_data_2', 'w'))

# %%
print(best)
# Out:
# {'motor_transform': 2.0}

# %% [markdown]
# It got the same result so I guess it's time to look at the graphs.

# %%
data = ctn_benchmark.Data('data')
df = pandas.DataFrame(data.data)
df = df[df._result_feedback == 0.4195086163487056]
df = df[df._AIT_r_transform == 0.8079719992231219]
df = df[df._V1_r_transform == 0.11090645719111913]
df = df[df._AIT_V1_strength == 0.06848695023305285]
df = df[df._compare_to_result_strength == 0.12966085928477078]
df = df[df._motor_feedback == 0.06848695023305285]
df


fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_motor_transform'
sns.regplot(x, y = 'PMC_to_MC', ax = ax1, data = df)
sns.regplot(x, y = 'MC_to_finger', ax = ax2, data = df)
sns.regplot(x, y = 'finger_to_end', ax = ax3, data = df)

# %% [markdown]
# Well... 2.0 looks like the best value.
