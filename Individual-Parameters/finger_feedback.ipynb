# %%
import sys
sys.path.append('../')

# %%
import ctn_benchmark

# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from hyperopt import fmin, hp, tpe, Trials, rand
import pickle
import hyperopt

# %%
import vision_benchmarks
reload (vision_benchmarks)
# Out:
# <module 'vision_benchmarks' from '../vision_benchmarks.pyc'>

# %%
def objective(x):
    vals = vision_benchmarks.Vision_Model().run(
        #motor_feedback = x['motor_feedback'],
        #motor_transform = x['motor_transform'],
        finger_feedback = x['finger_feedback'],
        #motor_to_fingers_strength = x['motor_to_fingers_strength']
    )
    return {
        'loss': 
            abs(vals['MC_to_finger'] - 0.025) + abs(vals['finger_to_end'] - 0.03) + abs(vals['PMC_to_MC'] - 0.025),
        
        'status': hyperopt.STATUS_OK,
    }
trials = Trials()
best = fmin(objective,
            space = {#'motor_feedback': hp.uniform('motor_feedback', 0, 1),
                     #'motor_transform': hp.quniform('motor_transform', 0, 15, 1),
                     'finger_feedback': hp.uniform('finger_feedback', 0, 1),
                     #'motor_to_fingers_strength': hp.uniform('motor_to_fingers_strength', 0, 1)
                    },
            algo = rand.suggest,
            max_evals = 100,
            trials = trials
           )
pickle.dump({'Trials': trials, 'Best': best}, open ('finger_feedback_data', 'w'))
# Out:
# running Vision_Model#20160729-174138-6ee3e16b
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.6964691855978616
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174224-7739df34
# Simulation finished in 0:00:31.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.10606490595473272
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174314-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.50672601149957
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174359-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.10517212721767522
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174443-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5238333199546759
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174527-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8666370428503979
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174611-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5705316251454068
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174654-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.1416302690767407
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0049999999999999906
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174740-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.650153605471749
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174825-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.7809038987924661
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174911-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.4195086163487056
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.030999999999999986
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-174956-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8114036263085849
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175040-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.6613289424499647
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175126-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.15321593689979662
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0049999999999999906
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175209-7739df34
# Simulation finished in 0:00:33.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9438502081196458
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032999999999999988
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175301-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.7493422613186888
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175344-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.4909623875237653
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175428-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.7479055164963537
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175517-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9173854839516489
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175602-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9020615248125082
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175650-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.7377549616506409
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175736-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.09334405798000733
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175819-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.28304194766654334
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.020000000000000004
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175902-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.4981094352456573
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-175946-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.36669556939777637
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.028000000000000011
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180029-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5754058522312349
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180112-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8813075509766621
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180155-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9085839385674503
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180238-7739df34
# Simulation finished in 0:00:31.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.7697943163974402
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180326-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9487277738884469
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180410-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.14769985292022558
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0049999999999999906
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180454-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5077237683672613
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180540-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.6523263257973545
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180624-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.31361950860293797
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0089999999999999941
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180707-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.7974020646840758
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180752-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.0962693408301577
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180835-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.7888463751831797
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-180918-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8333928248007452
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181001-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9406736056841625
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181045-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.3210000825092548
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181128-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.6889638548606529
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181229-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.356982731750056
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.023000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181316-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.826222888961089
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181403-7739df34
# Simulation finished in 0:00:37.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.29773903020981196
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.020000000000000004
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181458-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8983790484749181
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181544-7739df34
# Simulation finished in 0:00:41.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5977987504943293
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181643-7739df34
# Simulation finished in 0:00:33.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.6695907794784146
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181737-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.05264541759779817
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181823-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.6577461784201639
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-181906-7739df34
# Simulation finished in 0:00:38.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.14940184445609295
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0049999999999999906
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182002-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.09325747955255803
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182048-7739df34
# Simulation finished in 0:00:41.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.46003873368799186
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182150-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8020878465307703
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182236-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.3574378113049097
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.020000000000000004
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182335-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5028311147323427
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182423-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5245962526605522
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182506-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9504550464921385
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182549-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5627230998985673
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182634-7739df34
# Simulation finished in 0:00:40.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.524023109374771
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-182732-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8765671957002212
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# ...
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8479000603201088
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.025000000000000008
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-184444-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9305565555045975
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-184528-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9602607053363932
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-184612-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.42732424288263793
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-184655-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5029648605599233
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-184738-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.11090645719111913
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-184822-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.8432838236774246
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-184905-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.09992421021977205
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-184948-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.7813680777780895
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185032-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.23290163402733643
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0049999999999999906
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185115-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.2184265373924411
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0049999999999999906
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185159-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.04824402823763607
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185242-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.15392158973477588
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0049999999999999906
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185325-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.035589034976299394
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.0040000000000000036
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185425-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.10366168624048644
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0059999999999999915
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185516-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.3342536906326542
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.020000000000000004
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185559-7739df34
# Simulation finished in 0:00:43.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.013493404710812285
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.0030000000000000027
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185700-7739df34
# Simulation finished in 0:00:34.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.3601522106183571
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.023000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185801-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5465707341983469
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999985
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160729-185902-7739df34
# Simulation finished in 0:00:25.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.5260284260841477
# _motor_to_fingers_strength = 0.8079719992231219
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.032000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001

# %%
print(best)
# Out:
# {'finger_feedback': 0.6964691855978616}

# %% [markdown]
# How does this compare to the origional hyperopt value? It was closeish -  the initial value was 0.4195086163487056.

# %%
import pandas
import seaborn as sns
data = ctn_benchmark.Data('data')
df = pandas.DataFrame(data.data)

# %%
df = df[df._result_feedback == 0.4195086163487056]
df = df[df._AIT_r_transform == 0.8079719992231219]
df = df[df._V1_r_transform == 0.11090645719111913]
df = df[df._AIT_V1_strength == 0.06848695023305285]
df = df[df._compare_to_result_strength == 0.12966085928477078]
df = df[df._motor_transform == 2.0]
df = df[df._motor_feedback == 0.06848695023305285]
df

fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_finger_feedback'
sns.regplot(x, y = 'PMC_to_MC', ax = ax1, data = df)
sns.regplot(x, y = 'MC_to_finger', ax = ax2, data = df)
sns.regplot(x, y = 'finger_to_end', ax = ax3, data = df)
