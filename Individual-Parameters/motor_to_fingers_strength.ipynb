# %%
import sys
sys.path.append('../')

# %%
import ctn_benchmark

# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from hyperopt import fmin, hp, tpe, Trials, rand
import pickle
import hyperopt

# %%
import vision_benchmarks
reload (vision_benchmarks)
# Out:
# <module 'vision_benchmarks' from '../vision_benchmarks.pyc'>

# %%
def objective(x):
    vals = vision_benchmarks.Vision_Model().run(
        #motor_feedback = x['motor_feedback'],
        #motor_transform = x['motor_transform'],
        #finger_feedback = x['finger_feedback'],
        motor_to_fingers_strength = x['motor_to_fingers_strength']
    )
    return {
        'loss': 
            abs(vals['MC_to_finger'] - 0.025) + abs(vals['finger_to_end'] - 0.03) + abs(vals['PMC_to_MC'] - 0.025),
        
        'status': hyperopt.STATUS_OK,
    }
trials = Trials()
best = fmin(objective,
            space = {#'motor_feedback': hp.uniform('motor_feedback', 0, 1),
                     #'motor_transform': hp.quniform('motor_transform', 0, 15, 1),
                     #'finger_feedback': hp.uniform('finger_feedback', 0, 1),
                     'motor_to_fingers_strength': hp.uniform('motor_to_fingers_strength', 0, 1)
                    },
            algo = rand.suggest,
            max_evals = 100,
            trials = trials
           )
pickle.dump({'Trials': trials, 'Best': best}, open ('motor_to_fingers_strength_data', 'w'))
# Out:
# running Vision_Model#20160802-103351-2759f760
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.6964691855978616
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.052000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.044999999999999984
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-103438-7739df34
# Simulation finished in 0:00:36.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.10606490595473272
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-103536-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.50672601149957
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.13300000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.095000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-103631-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.10517212721767522
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-103719-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5238333199546759
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.14200000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.064999999999999974
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-103803-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8666370428503979
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.017000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.028999999999999998
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-103850-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5705316251454068
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.10199999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.063
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-103935-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.1416302690767407
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104022-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.650153605471749
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.06699999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.051000000000000018
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104110-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.7809038987924661
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.036999999999999991
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104203-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.4195086163487056
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.19800000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.25
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104248-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8114036263085849
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.031
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104335-7739df34
# Simulation finished in 0:00:39.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.6613289424499647
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.062999999999999987
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.036000000000000004
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104438-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.15321593689979662
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104529-7739df34
# Simulation finished in 0:00:32.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9438502081196458
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.0089999999999999941
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.021000000000000005
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104625-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.7493422613186888
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.051000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024999999999999994
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104711-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.4909623875237653
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.14700000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.10700000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104755-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.7479055164963537
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.042999999999999997
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.033000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104840-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9173854839516489
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.012999999999999998
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.022999999999999993
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-104924-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9020615248125082
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.012999999999999998
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.022000000000000006
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105008-7739df34
# Simulation finished in 0:00:31.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.7377549616506409
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.053000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105057-7739df34
# Simulation finished in 0:00:30.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.09334405798000733
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105152-7739df34
# Simulation finished in 0:00:37.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.28304194766654334
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105254-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.4981094352456573
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.15000000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.095000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105343-7739df34
# Simulation finished in 0:00:34.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.36669556939777637
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.42399999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.091999999999999971
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105437-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5754058522312349
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.084000000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.070000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105530-7739df34
# Simulation finished in 0:00:31.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8813075509766621
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.014999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.025999999999999995
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105619-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9085839385674503
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.012999999999999998
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.026999999999999996
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105704-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.7697943163974402
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.037999999999999992
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.027999999999999997
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105748-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9487277738884469
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.0079999999999999932
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105833-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.14769985292022558
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-105922-7739df34
# Simulation finished in 0:00:41.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5077237683672613
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.14000000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.084999999999999992
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110022-7739df34
# Simulation finished in 0:00:33.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.6523263257973545
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.054000000000000006
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.063
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110119-7739df34
# Simulation finished in 0:00:29.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.31361950860293797
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110213-7739df34
# Simulation finished in 0:00:28.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.7974020646840758
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.034000000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.023000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110259-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.0962693408301577
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110349-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.7888463751831797
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.03599999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.02200000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110433-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8333928248007452
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.020000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.031
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110517-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9406736056841625
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.0089999999999999941
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.026000000000000009
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110603-7739df34
# Simulation finished in 0:00:31.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.3210000825092548
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110652-7739df34
# Simulation finished in 0:00:34.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.6889638548606529
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.054000000000000006
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.03999999999999998
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110744-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.356982731750056
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.58900000000000008
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.21400000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110828-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.826222888961089
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.020999999999999991
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.034000000000000016
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110913-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.29773903020981196
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-110957-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8983790484749181
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.013999999999999999
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.024999999999999994
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111044-7739df34
# Simulation finished in 0:00:32.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5977987504943293
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.090000000000000011
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.053999999999999992
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111135-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.6695907794784146
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.060999999999999985
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.038000000000000006
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111242-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.05264541759779817
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111327-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.6577461784201639
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.063999999999999987
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.036000000000000004
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111411-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.14940184445609295
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111455-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.09325747955255803
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111540-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.46003873368799186
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.193
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.123
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111624-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8020878465307703
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.033000000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.023000000000000007
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111708-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.3574378113049097
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.58900000000000008
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.21400000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111808-7739df34
# Simulation finished in 0:00:42.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5028311147323427
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.14500000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.07099999999999998
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-111916-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5245962526605522
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.14200000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.063999999999999974
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-112001-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9504550464921385
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.0079999999999999932
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.018000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-112045-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5627230998985673
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.11600000000000001
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.036000000000000004
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-112129-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.524023109374771
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.14200000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.064999999999999974
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-112214-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8765671957002212
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.016
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# ...
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8479000603201088
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.018000000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.029999999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-113837-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9305565555045975
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.009999999999999995
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.022000000000000006
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-113922-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.9602607053363932
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.0069999999999999923
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.021000000000000005
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114006-7739df34
# Simulation finished in 0:00:27.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.42732424288263793
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.27299999999999996
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.14300000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114051-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5029648605599233
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.14500000000000002
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.090999999999999998
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114135-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.11090645719111913
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114219-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.8432838236774246
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.020000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.034000000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114304-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.09992421021977205
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114348-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.7813680777780895
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.036999999999999991
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.032000000000000001
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114433-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.23290163402733643
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114517-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.2184265373924411
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114602-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.04824402823763607
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114646-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.15392158973477588
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114731-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.035589034976299394
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114815-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.10366168624048644
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114900-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.3342536906326542
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-114944-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.013493404710812285
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = -0.083000000000000004
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.45800000000000002
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-115028-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.3601522106183571
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.55300000000000005
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = -0.17799999999999999
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-115113-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5465707341983469
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.098999999999999991
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.086000000000000021
# retina_to_V1 = 0.0050000000000000001
# running Vision_Model#20160802-115158-7739df34
# Simulation finished in 0:00:26.
# _runtime = 2
# _result_feedback = 0.4195086163487056
# _compare_to_result_strength = 0.12966085928477078
# _D = 32
# _motor_feedback = 0.06848695023305285
# _motor_transform = 2.0
# _finger_feedback = 0.9603352183200515
# _motor_to_fingers_strength = 0.5260284260841477
# _AIT_V1_strength = 0.06848695023305285
# _V1_r_transform = 0.11090645719111913
# _AIT_r_transform = 0.8079719992231219
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# AIT_to_PFC = 0.022000000000000002
# MC_to_finger = 0.127
# PFC_to_PMC = 0.020000000000000004
# PMC_to_MC = 0.013999999999999999
# V1_to_AIT = 0.023
# finger_to_end = 0.075000000000000039
# retina_to_V1 = 0.0050000000000000001

# %%
print(best)
# Out:
# {'motor_to_fingers_strength': 0.8333928248007452}

# %% [markdown]
# How does this compare to the origional hyperopt value? It's very very close - the origional value found by multiparameter hyperopt was 0.8079719992231219.

# %%
import pandas
import seaborn as sns
data = ctn_benchmark.Data('data')
df = pandas.DataFrame(data.data)

# %%
df = df[df._result_feedback == 0.4195086163487056]
df = df[df._AIT_r_transform == 0.8079719992231219]
df = df[df._V1_r_transform == 0.11090645719111913]
df = df[df._AIT_V1_strength == 0.06848695023305285]
df = df[df._compare_to_result_strength == 0.12966085928477078]
df = df[df._motor_transform == 2.0]
df = df[df._motor_feedback == 0.06848695023305285]
df = df[df._finger_feedback == 0.9603352183200515]

df

fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_motor_to_fingers_strength'
sns.regplot(x, y = 'PMC_to_MC', ax = ax1, data = df)
sns.regplot(x, y = 'MC_to_finger', ax = ax2, data = df)
sns.regplot(x, y = 'finger_to_end', ax = ax3, data = df)

# %% [markdown]
# It looks like this parameter only starts to effect the value of the MC_to_finger latency when it's value is above 0.3. Something is happening there.
